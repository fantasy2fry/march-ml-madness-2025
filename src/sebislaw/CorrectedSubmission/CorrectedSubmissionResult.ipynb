# %%
import numpy as np
import pandas as pd
solution = pd.read_csv('finalsolution2025.csv')[['ID', 'Pred']]
old_submission = pd.read_csv('LogisticRegressionWithElo_NEW.csv')
corrected_submission = pd.read_csv('LogisticRegressionWithElo_NEW_corrected_train_2024.csv')

# %%
# Submitted, fit on 2010-2023
df = pd.merge(solution, old_submission, on='ID', how='left')
np.mean((df['Pred_x']-df['Pred_y'])**2)
# Out:
# 0.1465888879794976

# %%
# Submitted, fit on 2024
df = pd.merge(solution, corrected_submission, on='ID', how='left')
np.mean((df['Pred_x']-df['Pred_y'])**2)
# Out:
# 0.12924049079857117
